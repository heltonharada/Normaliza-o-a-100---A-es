# %%
import yfinance as yf

# %%
import matplotlib.pyplot as plt

# %%
serie_vale = yf.download('VALE3.SA', start='2015-01-01', end='2022-01-28', rounding=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(serie_vale)
# Out:
# pandas.core.frame.DataFrame

# %%
serie_vale.head(5)
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2015-01-02  21.70  21.95  21.06  21.28      14.68  5658400
# 2015-01-05  20.76  21.13  20.51  20.96      14.46  8603000
# 2015-01-06  21.07  22.13  21.07  21.80      15.04  9879900
# 2015-01-07  22.32  22.81  21.97  22.60      15.59  6130900
# 2015-01-08  22.77  22.88  22.11  22.84      15.76  4667300

# %%
plt.figure(figsize=(20,10), facecolor='white')
plt.plot(serie_vale['Adj Close'], 'r--')
plt.title('VALE3', fontsize=30, loc='Left')
plt.xlabel('Data', fontsize=15)
plt.ylabel('Preço', fontsize=15)
plt.show()

# %%
serie_petr = yf.download('PETR4.SA', start='2015-01-01', end='2022-01-28', rounding=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
serie_petr.head(5)
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2015-01-02  9.99  9.99  9.35   9.36       7.06  49559500
# 2015-01-05  9.14  9.19  8.53   8.56       6.45  78385100
# 2015-01-06  8.71  8.83  8.04   8.28       6.24  84723300
# 2015-01-07  8.56  8.73  8.36   8.67       6.54  85531000
# 2015-01-08  8.79  9.39  8.74   9.23       6.96  83306300

# %%
plt.figure(figsize=(20,10), facecolor='white')
plt.plot(serie_petr['Adj Close'])
plt.title('PETR4', fontsize=30, loc='Left')
plt.xlabel('Data', fontsize=15)
plt.ylabel('Preço', fontsize=15)
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame((serie_vale['Adj Close'], serie_petr['Adj Close'])).T

# %%
df.head()
# Out:
#             Adj Close  Adj Close
# Date
# 2015-01-02      14.68       7.06
# 2015-01-05      14.46       6.45
# 2015-01-06      15.04       6.24
# 2015-01-07      15.59       6.54
# 2015-01-08      15.76       6.96

# %%
df.columns = ['Fech VALE3', 'Fech PETR4']
df.head()
# Out:
#             Fech VALE3  Fech PETR4
# Date
# 2015-01-02       14.68        7.06
# 2015-01-05       14.46        6.45
# 2015-01-06       15.04        6.24
# 2015-01-07       15.59        6.54
# 2015-01-08       15.76        6.96

# %%
plt.figure(figsize=[20,10], facecolor='white')
plt.plot((df['Fech VALE3'] / df['Fech VALE3'].iloc[0] * 100), color='red')
plt.plot((df['Fech PETR4'] / df['Fech PETR4'].iloc[0] * 100), color='blue')
plt.title('Comparação Normalizada a 100', fontsize=15)
plt.xlabel('Data')
plt.ylabel('Preço')
plt.legend(['Vale3, Petr4'])
plt.show()
